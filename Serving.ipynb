# %%
# STEP 1: INSTALL DEPENDENCIES
# !pip install pandas numpy scikit-learn imbalanced-learn mlflow joblib matplotlib seaborn
# !pip install -U imbalanced-learn
# !pip install dagshub
# !pip install dagshub mlflow
# !pip install mlflow==2.19.0 pandas scikit-learn flask gunicorn
# Out:
# ...
# WARNING: Ignoring invalid distribution ~lflow (C:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lflow-skinny (C:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lflow (C:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lflow-skinny (C:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lflow (C:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lflow-skinny (C:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# WARNING: Ignoring invalid distribution ~lflow (C:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# ...

# %%
from flask import Flask, request, jsonify
from werkzeug.middleware.dispatcher import DispatcherMiddleware
from prometheus_client import make_wsgi_app, Counter, Histogram, Gauge, Info
import mlflow
import pandas as pd
import time
import os
import sys

# Konfigurasi Server
app = Flask ('serving_model')
HOST_IP = '127.0.0.1'
PORT_NUM = 5001
EXPERIMENT_NAME = "Modeling MSML"

print("="*80)
print(f"BOOK POPULARITY MODEL - SERVING ON PORT {PORT_NUM}")
print("="*80)
# Out:
# ...
# BOOK POPULARITY MODEL - SERVING ON PORT 5001
# ...

# %%
# %pip install --upgrade requests mlflow

# Set URI ke folder lokal
mlflow.set_tracking_uri("file:./mlruns")
print("✓ Folder 'mlruns' terdeteksi.")
# Out:
# ...
#   Using cached mlflow_skinny-3.8.0-py3-none-any.whl.metadata (31 kB)
# ...
# Using cached mlflow_skinny-3.8.0-py3-none-any.whl (2.5 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~lflow (c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lflow-skinny (c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lflow (c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lflow-skinny (c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages)
#   WARNING: Failed to write executable - trying to use .deleteme logic
# ...
